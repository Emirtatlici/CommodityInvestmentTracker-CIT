# %%
from deniyorum import  CommodityInvestmentAnalyzer

# %%
cia=CommodityInvestmentAnalyzer()

# %%
data_silver= cia.get_commodity_data(start_date="17-07-2017",commodity_type="silver")
data_gold= cia.get_commodity_data(start_date="17-07-2017",commodity_type="gold")
print(data_gold.head(2))
print(data_silver.head(2))
# Out:
#             Gold_USD_Price
# Date
# 16-07-2017        1234.046
# 17-07-2017        1242.414
#             Silver_USD_Price
# Date
# 16-07-2017          16.11170
# 17-07-2017          16.29144

# %%
data_gold
# Out:
#             Gold_USD_Price
# Date
# 16-07-2017        1234.046
# 17-07-2017        1242.414
# 18-07-2017        1241.233
# 19-07-2017        1244.559
# 20-07-2017        1254.984
# ...                    ...
# 15-08-2024        2508.140
# 18-08-2024        2504.285
# 19-08-2024        2514.110
# 20-08-2024        2512.250
# 21-08-2024        2506.495
#
# [1844 rows x 1 columns]

# %%
results = cia.analyze_and_plot_periodic_investment(
    df=data_gold,
    start_date="17-07-2021",
    end_date="17-07-2024",
    interval_days=30,
    investment_amount=500,
    commodity_type="Gold"
)

# %%
cia.compare_commodities(start_date="17-07-2021",end_date="17-07-2023")
# Out:
# Performance Comparison:
# Gold return: 9.16%
# Silver return: -0.49%
