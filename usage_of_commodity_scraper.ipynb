# %%
from commodity_scraper import get_commodity_data,analyze_investment

# %%
data=get_commodity_data()

# %%
results=analyze_investment(data)
print(results)
# Out:
# ----------------------------------------
