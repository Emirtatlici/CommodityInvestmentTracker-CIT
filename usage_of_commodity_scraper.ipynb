# %%
from commodity_scraper import get_commodity_data,analyze_investment,save_to_excel

# %%
data=get_commodity_data()

# %%
data.head()
# Out:
#          Date  Gold_USD_Price
# 0  16-07-2017        1234.046
# 1  17-07-2017        1242.414
# 2  18-07-2017        1241.233
# 3  19-07-2017        1244.559
# 4  20-07-2017        1254.984

# %%
results=analyze_investment(data)
print(results)
# Out:
# ----------------------------------------

# %%
save_to_excel(data,"gold_prices.xlsx")
